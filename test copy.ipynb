# %%
from PSUTester import *
ps=PSUTester('fastTest.yaml')
ps.test_flow()
# Out:
# File Configuration
# Instrument Connection
# DC Power Supply 6705 at serial COM13 is open
# TENMA 72-13210 V3.21 SN:00018436 connected
# test boardCOM10 is open
# Instrument Initializing
# Test flow start
# Input configuration
# ---------------input configuration time0.31499409675598145
#
# Start unit test on channel 2
# set channel to 2
# ******DC test mode for channel 2******
# ---------------set DC test mode 5.831166744232178
# sampling DC
# input 24.3194V 0.058A  output 3.3456V 0.0988A
# input 24.3101V 0.09A  output 3.3378V 0.3233A
# input 24.3267V 0.125A  output 3.3261V 0.5486A
# input 24.3187V 0.16A  output 3.3197V 0.7733A
# input 24.3307V 0.197A  output 3.3126V 0.9984A
# efficiency test
# load test
# setting ac mode for ch2
# ---------------set AC test mode 0.18700551986694336
# sampling AC
#  0.0988A 0.0052VPP
#  0.3233A 0.0044VPP
#  0.5488A 0.0048VPP
#  0.7733A 0.0048VPP
#  0.9984A 0.004VPP
# ---------------unit test time72.0895094871521
#
# Start unit test on channel 4
# ...
