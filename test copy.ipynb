# %%
from PSUTester import *
ps=PSUTester('fastTest.yaml')
# Out:
# File Configuration
# Instrument Connection
# DC Power Supply 6705 at serial COM13 is open
# TENMA 72-13210 V3.21 SN:00018436 connected
# test boardCOM10 is open
# Instrument Initializing

# %%
ps.test_flow()
# Out:
# Test flow start
# Input configuration
#
# Start unit test on channel 2
# set channel to 2
# ******Set DC test mode for channel 2******
# sampling DC
# input 24.3914V 0.06A  output 0.0511984V 0.0988A
# input 24.387V 0.115A  output 0.0511984V 0.323A
# input 24.3948V 0.171A  output 0.0511984V 0.5486A
# input 24.3947V 0.228A  output 0.0511984V 0.7733A
# input 24.3759V 0.286A  output 0.2559922V 0.9984A
# setting ac mode for ch2
# sampling AC
#  0.0988A 0.0036VPP
#  0.3233A 9.91e+37VPP
#  0.5486A 0.0032VPP
#  0.7733A 9.91e+37VPP
#  0.9984A 9.91e+37VPP
#
# Start unit test on channel 3
# set channel to 3
# ******Set DC test mode for channel 3******
# sampling DC
# input 24.4034V 0.046A  output 5.4933V 0.0A
# input 24.3991V 0.046A  output 5.4916V 0.0A
# input 24.4039V 0.046A  output 5.4914V 0.0A
# input 24.4064V 0.046A  output 5.4921V 0.0A
# input 24.3992V 0.046A  output 5.4909V 0.0A
# setting ac mode for ch3
# sampling AC
#  0.0A 9.91e+37VPP
# ...

# %%
from TestBoard import *
p=TestBoard('COM10')
# Out:
# test boardCOM10 is open

# %%
p.set_channel(2)

# %%
p.set_channel(4)

# %%
p.close()
