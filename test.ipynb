# %%
from PSUTester import *
ps=PSUTester('fastTest.yaml')
ps.test_flow()
# Out:
# File Configuration
# Instrument Connection
# DC Power Supply 6705 at serial COM13 is open
# TENMA 72-13210 V3.21 SN:00018436 connected
# test boardCOM10 is open
# Instrument Initializing
# ***Test flow start
# ******Input configuration
# ******input configuration time0.31639599800109863
# ******unit test on channel 2
# *********DC test mode for channel 2
# *********set DC test mode 5.954808473587036
# *********get no load dC waveform
# *********get no load dC waveform1.6736924648284912
# *********sampling DC
# ************start point 0
# input 24.3782V 0.058A  output 3.3496V 0.0988A
# ************point 0:1.9943995475769043
# ************start point 1
# input 24.3773V 0.09A  output 3.3446V 0.323A
# ************point 1:1.9939918518066406
# ************start point 2
# input 24.3738V 0.125A  output 3.3343V 0.5486A
# ************point 2:2.0044074058532715
# ************start point 3
# input 24.3728V 0.161A  output 3.3272V 0.7731A
# ************point 3:2.019605875015259
# ...

# %%
import pyvisa as visa
rm=visa.ResourceManager()
rm.list_resources()
# Out:
# ('USB0::0x0699::0x0401::C020996::INSTR',
#  'ASRL3::INSTR',
#  'ASRL4::INSTR',
#  'ASRL6::INSTR',
#  'ASRL8::INSTR',
#  'ASRL27::INSTR')
