# %%
from PSUTester import *
ps=PSUTester('fastTest.yaml')
ps.test_flow()
# Out:
# File Configuration
# Instrument Connection
# DC Power Supply 6705 at serial COM13 is open
# TENMA 72-13210 V3.21 SN:00018436 connected
# test boardCOM10 is open
# Instrument Initializing
# Test flow start
# Input configuration
#
# Start unit test on channel 2
# set channel to 2
# ******Set DC test mode for channel 2******
# sampling DC
# input 24.4277V 0.058A  output 3.3492V 0.0988A
# input 24.442V 0.072A  output 3.3465V 0.1983A
# input 24.4364V 0.086A  output 3.3455V 0.2981A
# input 24.441V 0.101A  output 3.3419V 0.3985A
# input 24.4397V 0.117A  output 3.3394V 0.4985A
# input 24.4427V 0.133A  output 3.3343V 0.5981A
# input 24.4483V 0.149A  output 3.3314V 0.6984A
# input 24.4427V 0.165A  output 3.3304V 0.798A
# input 24.4471V 0.181A  output 3.3274V 0.8986A
# input 24.4378V 0.197A  output 3.325V 0.9979A
# setting ac mode for ch2
# sampling AC
#  0.0988A 0.0052VPP
#  0.1981A 0.0048VPP
#  0.2981A 0.0052VPP
#  0.3985A 0.0052VPP
#  0.4985A 0.0052VPP
#  0.5981A 0.0048VPP
# ...

# %%
from PSU_6705 import *

# %%
u=PSU_6705('COM13')
# Out:
# DC Power Supply 6705 at serial COM13 is open

# %%
u.off()

# %%
u.on()
