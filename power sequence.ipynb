# %%
from PSUTester import *
ps=PSUTester('fastTest.yaml')
ps.test_flow()
# Out:
# File Configuration
# Instrument Connection
# DC Power Supply 6705 at serial COM13 is open
# TENMA 72-13210 V3.21 SN:00018436 connected
# test boardCOM10 is open
# Instrument Initializing
# Test flow start
# Input configuration
#
# Start unit test on channel 2
# set channel to 2
# ******DC test mode for channel 2******
# sampling DC
# input 24.4445V 0.058A  output 3.3522V 0.0988A
# input 24.4683V 0.125A  output 3.3376V 0.5483A
# input 24.4376V 0.197A  output 3.3264V 0.9981A
# setting ac mode for ch2
# sampling AC
#  0.0988A 0.0052VPP
#  0.5483A 0.0048VPP
#  0.9981A 0.0052VPP
#
# Start unit test on channel 4
# set channel to 4
# ******DC test mode for channel 4******
# sampling DC
# input 24.4614V 0.082A  output 5.4841V 0.1483A
# input 24.4492V 0.25A  output 5.4632V 0.8229A
# input 24.4375V 0.426A  output 5.4446V 1.4985A
# setting ac mode for ch4
# sampling AC
#  0.1483A 0.012VPP
#  0.8229A 0.0144VPP
#  1.4985A 0.014VPP
# ...

# %%
from Oscilloscope import *
osc=Oscilloscope('USB0::0x0699::0x0401::C020996::INSTR')

# %%
osc.get_immed_value(1,'AMPlitude')
# Out:
# 9.91e+37

# %%
osc.query("*SRE?")
# Out:
# '0'

# %%
osc.query("ALLEv?")
# Out:
# '1,"No events to report - new events pending *ESR?"'

# %%
osc.query("*ESR?")
# Out:
# '16'

# %%
print(osc.query("EVMsg?"))
# Out:
# 2228,"Measurement error, Positive Clipping"
